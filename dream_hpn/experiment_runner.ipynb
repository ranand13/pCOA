# %%
import sys
sys.path.append('dream_hpn_code_modules')

from dream_hpn_runner import DreamHPNRunner

# %%
runner = DreamHPNRunner(verbose=True)
results = runner.run(force_recompute=False, save_protein_errors=True)
# Out:
# ...
# HPN-DREAM MCF7 BREAST CANCER SIGNALING
# ...
# Cache: dream_hpn_cache
#
# ...
# LOADING DATA
# ...
# Training: 127 DMSO samples
# Testing: 17 perturbations
# Proteins: 7 ['AKT', 'EGFR', 'GSK3', 'MAPK', 'MEK', 'mTOR', 'PDK1']
# Edges: 8
#
# ...
# FITTING ODE MODELS
# ...
# Loaded from cache
#
# ...
# GENERATING SYNTHETIC DATA
# ...
# Loaded from cache
#
# ...
# PCOA STRUCTURE DISCOVERY
# ...
#
# [Algorithm 1] Equation Rewriting
# ------------------------------------------------------------
#
# ...
# PHASE 1: CLUSTER-FOCUSED
# ...
#
# === Iteration 0 ===
#   Problematic clusters: 2
#     C0: vars=['AKT', 'mTOR']
#     C1: vars=['MAPK', 'MEK']
#   Cluster equations: 4
#   Pairs to try: 0
#   Found 0 candidates
#
# ...
# PHASE 2: FULL SWEEP
# ...
#
# === Full Sweep Iteration 0 ===
#   Pairs to try: 1
#   Found 1 candidates
#   GSK3_mTOR' ← f_GSK3 + f_mTOR (I_AKT*k_AKT_mTO, -I_AKT*k_AKT_GS): 0p + 1v
#     Variables: ['GSK3', 'mTOR']
#
# === Full Sweep Iteration 1 ===
#   Pairs to try: 2
#   Found 0 candidates
#
#   Phase 2 added 1 equations
#
# ...
